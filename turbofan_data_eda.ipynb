# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df1 = pd.read_csv('train_FD001.csv')

# %%
train_df1.iloc[0:198]
# Out:
#      unit_number  time  op_setting1  op_setting2  op_setting3  \
# 0              1     1      -0.0007      -0.0004        100.0
# 1              1     2       0.0019      -0.0003        100.0
# 2              1     3      -0.0043       0.0003        100.0
# 3              1     4       0.0007       0.0000        100.0
# 4              1     5      -0.0019      -0.0002        100.0
# ..           ...   ...          ...          ...          ...
# 193            2     2       0.0043      -0.0003        100.0
# 194            2     3       0.0018       0.0003        100.0
# 195            2     4       0.0035      -0.0004        100.0
# 196            2     5       0.0005       0.0004        100.0
# 197            2     6      -0.0010       0.0004        100.0
#
#      sen_measurement1  sen_measurement2  sen_measurement3  sen_measurement4  \
# 0              518.67            641.82           1589.70           1400.60
# 1              518.67            642.15           1591.82           1403.14
# 2              518.67            642.35           1587.99           1404.20
# 3              518.67            642.35           1582.79           1401.87
# 4              518.67            642.37           1582.85           1406.22
# ..                ...               ...               ...               ...
# 193            518.67            641.82           1587.05           1393.13
# 194            518.67            641.55           1588.32           1398.96
# 195            518.67            641.68           1584.15           1396.08
# 196            518.67            641.73           1579.03           1402.52
# 197            518.67            641.30           1577.50           1396.76
#
#      sen_measurement5  ...  sen_measurement13  sen_measurement14  \
# 0               14.62  ...            2388.02            8138.62
# 1               14.62  ...            2388.07            8131.49
# 2               14.62  ...            2388.03            8133.23
# 3               14.62  ...            2388.08            8133.83
# 4               14.62  ...            2388.04            8133.80
# ..                ...  ...                ...                ...
# 193             14.62  ...            2387.98            8131.09
# 194             14.62  ...            2387.99            8140.58
# 195             14.62  ...            2387.93            8140.44
# 196             14.62  ...            2387.94            8136.67
# 197             14.62  ...            2387.99            8133.65
#
#      sen_measurement15  sen_measurement16  sen_measurement17  \
# 0               8.4195               0.03                392
# 1               8.4318               0.03                392
# 2               8.4178               0.03                390
# 3               8.3682               0.03                392
# 4               8.4294               0.03                393
# ..                 ...                ...                ...
# 193             8.4167               0.03                392
# 194             8.3802               0.03                391
# 195             8.4018               0.03                391
# 196             8.3867               0.03                390
# 197             8.3800               0.03                392
#
#      sen_measurement18  sen_measurement19  sen_measurement20  \
# 0                 2388              100.0              39.06
# 1                 2388              100.0              39.00
# 2                 2388              100.0              38.95
# 3                 2388              100.0              38.88
# 4                 2388              100.0              38.90
# ..                 ...                ...                ...
# 193               2388              100.0              39.06
# 194               2388              100.0              39.11
# 195               2388              100.0              39.13
# 196               2388              100.0              39.18
# 197               2388              100.0              39.15
#
#      sen_measurement21  RUL
# 0              23.4190  191
# 1              23.4236  190
# 2              23.3442  189
# 3              23.3739  188
# 4              23.4044  187
# ..                 ...  ...
# 193            23.4085  285
# 194            23.4250  284
# 195            23.5027  283
# 196            23.4234  282
# 197            23.4270  281
#
# [198 rows x 27 columns]

# %%
train_df1.describe()
# Out:
#         unit_number          time   op_setting1   op_setting2  op_setting3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000      20631.0
# mean      51.506568    108.807862     -0.000009      0.000002        100.0
# std       29.227633     68.880990      0.002187      0.000293          0.0
# min        1.000000      1.000000     -0.008700     -0.000600        100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200        100.0
# 50%       52.000000    104.000000      0.000000      0.000000        100.0
# 75%       77.000000    156.000000      0.001500      0.000300        100.0
# max      100.000000    362.000000      0.008700      0.000600        100.0
#
#        sen_measurement1  sen_measurement2  sen_measurement3  sen_measurement4  \
# count          20631.00      20631.000000      20631.000000      20631.000000
# mean             518.67        642.680934       1590.523119       1408.933782
# std                0.00          0.500053          6.131150          9.000605
# min              518.67        641.210000       1571.040000       1382.250000
# 25%              518.67        642.325000       1586.260000       1402.360000
# 50%              518.67        642.640000       1590.100000       1408.040000
# 75%              518.67        643.000000       1594.380000       1414.555000
# max              518.67        644.530000       1616.910000       1441.490000
#
#        sen_measurement5  ...  sen_measurement13  sen_measurement14  \
# count      2.063100e+04  ...       20631.000000       20631.000000
# mean       1.462000e+01  ...        2388.096152        8143.752722
# std        1.776400e-15  ...           0.071919          19.076176
# min        1.462000e+01  ...        2387.880000        8099.940000
# 25%        1.462000e+01  ...        2388.040000        8133.245000
# 50%        1.462000e+01  ...        2388.090000        8140.540000
# 75%        1.462000e+01  ...        2388.140000        8148.310000
# max        1.462000e+01  ...        2388.560000        8293.720000
#
#        sen_measurement15  sen_measurement16  sen_measurement17  \
# count       20631.000000       2.063100e+04       20631.000000
# mean            8.442146       3.000000e-02         393.210654
# std             0.037505       1.387812e-17           1.548763
# min             8.324900       3.000000e-02         388.000000
# 25%             8.414900       3.000000e-02         392.000000
# 50%             8.438900       3.000000e-02         393.000000
# 75%             8.465600       3.000000e-02         394.000000
# max             8.584800       3.000000e-02         400.000000
#
#        sen_measurement18  sen_measurement19  sen_measurement20  \
# count            20631.0            20631.0       20631.000000
# mean              2388.0              100.0          38.816271
# std                  0.0                0.0           0.180746
# min               2388.0              100.0          38.140000
# 25%               2388.0              100.0          38.700000
# 50%               2388.0              100.0          38.830000
# 75%               2388.0              100.0          38.950000
# max               2388.0              100.0          39.430000
#
#        sen_measurement21           RUL
# count       20631.000000  20631.000000
# mean           23.289705    107.807862
# std             0.108251     68.880990
# min            22.894200      0.000000
# 25%            23.221800     51.000000
# 50%            23.297900    103.000000
# 75%            23.366800    155.000000
# max            23.618400    361.000000
#
# [8 rows x 27 columns]

# %%
train_df1.nunique()
# Out:
# unit_number           100
# time                  362
# op_setting1           158
# op_setting2            13
# op_setting3             1
# sen_measurement1        1
# sen_measurement2      310
# sen_measurement3     3012
# sen_measurement4     4051
# sen_measurement5        1
# sen_measurement6        2
# sen_measurement7      513
# sen_measurement8       53
# sen_measurement9     6403
# sen_measurement10       1
# sen_measurement11     159
# sen_measurement12     427
# sen_measurement13      56
# sen_measurement14    6078
# sen_measurement15    1918
# sen_measurement16       1
# sen_measurement17      13
# sen_measurement18       1
# sen_measurement19       1
# sen_measurement20     120
# sen_measurement21    4745
# RUL                   362
# dtype: int64

# %% [markdown]
# # Box Plot
# ## for each column

# %%
for x in train_df1:
    plt.figure()
    train_df1.boxplot([x])
# Out:
# C:\Users\DeTa5\AppData\Local\Temp\ipykernel_8460\2559479036.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# # Correlation Matrix

# %%
correlation_matrix = train_df1.corr()
plt.figure(figsize=(13,15))
sns.heatmap(correlation_matrix,annot=True, cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

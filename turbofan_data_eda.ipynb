# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df1 = pd.read_csv('train_FD001.csv')

# %%
train_df1.head()
# Out:
#    unit_number  time  op_setting1  op_setting2  op_setting3  sen_measurement1  \
# 0            1     1      -0.0007      -0.0004        100.0            518.67
# 1            1     2       0.0019      -0.0003        100.0            518.67
# 2            1     3      -0.0043       0.0003        100.0            518.67
# 3            1     4       0.0007       0.0000        100.0            518.67
# 4            1     5      -0.0019      -0.0002        100.0            518.67
#
#    sen_measurement2  sen_measurement3  sen_measurement4  sen_measurement5  \
# 0            641.82           1589.70           1400.60             14.62
# 1            642.15           1591.82           1403.14             14.62
# 2            642.35           1587.99           1404.20             14.62
# 3            642.35           1582.79           1401.87             14.62
# 4            642.37           1582.85           1406.22             14.62
#
#    ...  sen_measurement12  sen_measurement13  sen_measurement14  \
# 0  ...             521.66            2388.02            8138.62
# 1  ...             522.28            2388.07            8131.49
# 2  ...             522.42            2388.03            8133.23
# 3  ...             522.86            2388.08            8133.83
# 4  ...             522.19            2388.04            8133.80
#
#    sen_measurement15  sen_measurement16  sen_measurement17  sen_measurement18  \
# 0             8.4195               0.03                392               2388
# 1             8.4318               0.03                392               2388
# 2             8.4178               0.03                390               2388
# 3             8.3682               0.03                392               2388
# 4             8.4294               0.03                393               2388
#
#    sen_measurement19  sen_measurement20  sen_measurement21
# 0              100.0              39.06            23.4190
# 1              100.0              39.00            23.4236
# 2              100.0              38.95            23.3442
# 3              100.0              38.88            23.3739
# 4              100.0              38.90            23.4044
#
# [5 rows x 26 columns]

# %%
train_df1.describe()
# Out:
#         unit_number          time   op_setting1   op_setting2  op_setting3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000      20631.0
# mean      51.506568    108.807862     -0.000009      0.000002        100.0
# std       29.227633     68.880990      0.002187      0.000293          0.0
# min        1.000000      1.000000     -0.008700     -0.000600        100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200        100.0
# 50%       52.000000    104.000000      0.000000      0.000000        100.0
# 75%       77.000000    156.000000      0.001500      0.000300        100.0
# max      100.000000    362.000000      0.008700      0.000600        100.0
#
#        sen_measurement1  sen_measurement2  sen_measurement3  sen_measurement4  \
# count          20631.00      20631.000000      20631.000000      20631.000000
# mean             518.67        642.680934       1590.523119       1408.933782
# std                0.00          0.500053          6.131150          9.000605
# min              518.67        641.210000       1571.040000       1382.250000
# 25%              518.67        642.325000       1586.260000       1402.360000
# 50%              518.67        642.640000       1590.100000       1408.040000
# 75%              518.67        643.000000       1594.380000       1414.555000
# max              518.67        644.530000       1616.910000       1441.490000
#
#        sen_measurement5  ...  sen_measurement12  sen_measurement13  \
# count      2.063100e+04  ...       20631.000000       20631.000000
# mean       1.462000e+01  ...         521.413470        2388.096152
# std        1.776400e-15  ...           0.737553           0.071919
# min        1.462000e+01  ...         518.690000        2387.880000
# 25%        1.462000e+01  ...         520.960000        2388.040000
# 50%        1.462000e+01  ...         521.480000        2388.090000
# 75%        1.462000e+01  ...         521.950000        2388.140000
# max        1.462000e+01  ...         523.380000        2388.560000
#
#        sen_measurement14  sen_measurement15  sen_measurement16  \
# count       20631.000000       20631.000000       2.063100e+04
# mean         8143.752722           8.442146       3.000000e-02
# std            19.076176           0.037505       1.387812e-17
# min          8099.940000           8.324900       3.000000e-02
# 25%          8133.245000           8.414900       3.000000e-02
# 50%          8140.540000           8.438900       3.000000e-02
# 75%          8148.310000           8.465600       3.000000e-02
# max          8293.720000           8.584800       3.000000e-02
#
#        sen_measurement17  sen_measurement18  sen_measurement19  \
# count       20631.000000            20631.0            20631.0
# mean          393.210654             2388.0              100.0
# std             1.548763                0.0                0.0
# min           388.000000             2388.0              100.0
# 25%           392.000000             2388.0              100.0
# 50%           393.000000             2388.0              100.0
# 75%           394.000000             2388.0              100.0
# max           400.000000             2388.0              100.0
#
#        sen_measurement20  sen_measurement21
# count       20631.000000       20631.000000
# mean           38.816271          23.289705
# std             0.180746           0.108251
# min            38.140000          22.894200
# 25%            38.700000          23.221800
# 50%            38.830000          23.297900
# 75%            38.950000          23.366800
# max            39.430000          23.618400
#
# [8 rows x 26 columns]

# %%
train_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   unit_number        20631 non-null  int64
#  1   time               20631 non-null  int64
#  2   op_setting1        20631 non-null  float64
#  3   op_setting2        20631 non-null  float64
#  4   op_setting3        20631 non-null  float64
#  5   sen_measurement1   20631 non-null  float64
#  6   sen_measurement2   20631 non-null  float64
#  7   sen_measurement3   20631 non-null  float64
#  8   sen_measurement4   20631 non-null  float64
#  9   sen_measurement5   20631 non-null  float64
#  10  sen_measurement6   20631 non-null  float64
#  11  sen_measurement7   20631 non-null  float64
#  12  sen_measurement8   20631 non-null  float64
#  13  sen_measurement9   20631 non-null  float64
#  14  sen_measurement10  20631 non-null  float64
#  15  sen_measurement11  20631 non-null  float64
#  16  sen_measurement12  20631 non-null  float64
#  17  sen_measurement13  20631 non-null  float64
#  18  sen_measurement14  20631 non-null  float64
#  19  sen_measurement15  20631 non-null  float64
#  20  sen_measurement16  20631 non-null  float64
#  21  sen_measurement17  20631 non-null  int64
#  22  sen_measurement18  20631 non-null  int64
#  23  sen_measurement19  20631 non-null  float64
#  24  sen_measurement20  20631 non-null  float64
#  25  sen_measurement21  20631 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 4.1 MB

# %%
train_df1.nunique()
# Out:
# unit_number           100
# time                  362
# op_setting1           158
# op_setting2            13
# op_setting3             1
# sen_measurement1        1
# sen_measurement2      310
# sen_measurement3     3012
# sen_measurement4     4051
# sen_measurement5        1
# sen_measurement6        2
# sen_measurement7      513
# sen_measurement8       53
# sen_measurement9     6403
# sen_measurement10       1
# sen_measurement11     159
# sen_measurement12     427
# sen_measurement13      56
# sen_measurement14    6078
# sen_measurement15    1918
# sen_measurement16       1
# sen_measurement17      13
# sen_measurement18       1
# sen_measurement19       1
# sen_measurement20     120
# sen_measurement21    4745
# dtype: int64

# %% [markdown]
# # Correlation Matrix

# %%
correlation_matrix = train_df1.corr()
plt.figure(figsize=(13,13))
sns.heatmap(correlation_matrix,annot=True, cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
